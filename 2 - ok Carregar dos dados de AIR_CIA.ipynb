# %%
import pandas as pd  
from glob import glob

# %%
dados = sorted(glob(r'E:\Desafio Projetas\AIR_CIA\AIR_CIA\*.csv'))
dados
# Out:
# ['E:\\Desafio Projetas\\AIR_CIA\\AIR_CIA\\ANAC_20211220_203627.csv',
#  'E:\\Desafio Projetas\\AIR_CIA\\AIR_CIA\\ANAC_20211220_203643.csv',
#  'E:\\Desafio Projetas\\AIR_CIA\\AIR_CIA\\ANAC_20211220_203733.csv']

# %%
aereas = pd.concat((pd.read_csv(cont,sep=';') for cont in dados))

# %%
aereas
# Out:
#                                          Razão Social ICAO IATA  \
# 0                  ABSA - AEROLINHAS BRASILEIRAS S.A.    LTG M3
# 1   AEROSUL TÁXI AÉREO LTDA (EX.: AUSTEN TÁXI AÉRE...    ASO 2S
# 2   ASTA LINHAS AÉREAS LTDA ( EX - AMÉRICA DO SUL ...    SUL 0A
# 3                         ATA - AEROTÁXI ABAETÉ LTDA.       ABJ
# 4         AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)    ACN 2F
# 5                  AZUL LINHAS AÉREAS BRASILEIRAS S/A    AZU AD
# 6   GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS ...    GLO G3
# 7                        MAP TRANSPORTES AÉREOS LTDA.    PAM 7M
# 8                MODERN TRANSPORTE AEREO DE CARGA S.A    MWM WD
# 9                   PASSAREDO TRANSPORTES AÉREOS S.A.    PTB 2Z
# 10                        SIDERAL LINHAS AÉREAS LTDA.    SID 0S
# 11                             TAM LINHAS AÉREAS S.A.    TAM JJ
# 12                           TOTAL LINHAS AÉREAS S.A.    TTL L1
# 0   AEROSUL TÁXI AÉREO LTDA (EX.: AUSTEN TÁXI AÉRE...    ASO 2S
# ...
